# %%
import pandas as pd 

df = pd.read_csv('titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
cdf = df[['Age','Sex','Survived']]

# %%
# Fill missing age with mean
cdf['Age'] = cdf['Age'].fillna(cdf['Age'].mean())
cdf.Age.isna().sum()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17944\3528779701.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['Age'] = cdf['Age'].fillna(cdf['Age'].mean())
# 0

# %%
cdf.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# Encode Sex using binary
cdf['Sex'] = cdf['Sex'].map({'male': 1, 'female': 0})
cdf.Sex
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17944\3403856430.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['Sex'] = cdf['Sex'].map({'male': 1, 'female': 0})
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int64

# %%
# Split feature x and target y
# Combine age and sex only
x = cdf[['Age', 'Sex']]
y = cdf['Survived']

# %%
# Split into train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
# Model training using random forest
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=1)

# %%
# Accuracy
from sklearn.metrics import accuracy_score
y_pred = model.predict(x_test)
accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7932960893854749

# %%
# Export model to local
import joblib
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']

# %%
cdf
# Out:
#            Age  Sex  Survived
# 0    22.000000    1         0
# 1    38.000000    0         1
# 2    26.000000    0         1
# 3    35.000000    0         1
# 4    35.000000    1         0
# ..         ...  ...       ...
# 886  27.000000    1         0
# 887  19.000000    0         1
# 888  29.699118    0         0
# 889  26.000000    1         1
# 890  32.000000    1         0
#
# [891 rows x 3 columns]
